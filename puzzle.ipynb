# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
np.set_printoptions(threshold=np.inf)
# %matplotlib inline

# %%
mock = pd.read_json("https://s3.amazonaws.com/misc-file-snack/MOCK_SNACKER_DATA.json")
prod = pd.read_json("https://ca.desknibbles.com/products.json?limit=250")

# %%
uni = pd.unique(mock['fave_snack'])

# %%
mock[['email','fave_snack']]
# Out:
#                                 email                      fave_snack
# 0              gmcwhinnie0@sfgate.com                Hagenes and Sons
# 1         dellerey1@ezinearticles.com      Pollich, Mueller and Ratke
# 2          ccleugh2@ezinearticles.com                    Kautzer-Feil
# 3               tchalcroft3@github.io        Quigley, Kozey and Smith
# 4                pmcinnery4@mysql.com                  Koepp-Connelly
# 5          ebrearley5@theatlantic.com  Beatty, Weimann and Rutherford
# 6                hmanifield6@jugem.jp                       Grady LLC
# 7            igrummitt7@wikimedia.org                 Bashirian-Boyer
# 8        bosesnane8@blogtalkradio.com    O'Connell, Crist and Ullrich
# 9              mousley9@canalblog.com  Gleichner, Block and Halvorson
# 10                     ebunneya@de.vu                     Marks-Rohan
# 11         iomullanb@domainmarket.com                   Rath and Sons
# ...

# %%
print (type(prod.loc[0, 'products']));

df = pd.DataFrame(prod['products'].values.tolist())
vr = pd.DataFrame(df['variants'].values.tolist())
pr1 = pd.DataFrame(vr[0].values.tolist())

loc_arr = np.where(df['title'].isin(uni.tolist()))
pr2 = pr1.loc[loc_arr[0],'price']

pr2.astype(float)
print(type(pr2))

em = np.where(mock['fave_snack'].isin(df['title']))
mock.loc[em[0],'fave_snack']
mock.loc[em[0],'email']

how_many = np.unique(mock.loc[em[0],'fave_snack'],return_counts=True)
how_many = how_many[1]

how_many = int(how_many[0])

print(type(how_many))

total_price = pr2 * how_many

total_price
# Out:
# <class 'dict'>
# <class 'pandas.core.series.Series'>
# <class 'int'>
# 135    3.003.003.003.00
# 136    2.502.502.502.50
# Name: price, dtype: object

# %%
#df['title'].isin(mock['fave_snack'].tolist())
em = np.where(mock['fave_snack'].isin(df['title']))

# %%
em[0]

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
prod_flat = flatten_json(prod)
# flat = flatten_json(sample_object2)
json_normalize(prod_flat)

# %%
prod_flat['variants']

# %%
stock = np.where(df['title'].isin(uni.tolist()))

# %%
stock

# %%
mock.loc[em[0],'email']

# %%
em

# %%
r = requests.get('http://api.zippopotam.us/us/ma/belmont')
j = r.json()

data = json.loads(j)

print j['state']
print data['places']['latitude']

# %%
for i in prod['products']:
    print(i)
    
    for x in i:
        print(type(x))
# Out:
# {'id': 1336872108088, 'title': 'Blueberries (Pint)', 'handle': 'blueberries-pint', 'body_html': '', 'published_at': '2018-08-21T12:27:50-04:00', 'created_at': '2018-08-21T12:28:05-04:00', 'updated_at': '2018-08-21T12:28:05-04:00', 'vendor': 'Desk Nibbles', 'product_type': '', 'tags': [], 'variants': [{'id': 12244925874232, 'title': 'Default Title', 'option1': 'Default Title', 'option2': None, 'option3': None, 'sku': '', 'requires_shipping': True, 'taxable': False, 'featured_image': None, 'available': True, 'price': '0.00', 'grams': 0, 'compare_at_price': None, 'position': 1, 'product_id': 1336872108088, 'created_at': '2018-08-21T12:28:05-04:00', 'updated_at': '2018-09-12T12:20:42-04:00'}], 'images': [], 'options': [{'name': 'Title', 'position': 1, 'values': ['Default Title']}]}
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
import json
import requests

r = requests.get('https://ca.desknibbles.com/products.json?limit=250')
j = r.json()

data = json.loads(j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-d6e2dc387c08> in <module>()
#       5 j = r.json()
#       6
# ----> 7 data = json.loads(j)
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'dict'

# %%
df['variants']
# Out:
# 0      [{'id': 12244925874232, 'title': 'Default Titl...
# 1      [{'id': 12244925841464, 'title': 'Default Titl...
# 2      [{'id': 12244925808696, 'title': 'Default Titl...
# 3      [{'id': 12244925743160, 'title': 'Default Titl...
# 4      [{'id': 12244925710392, 'title': 'Default Titl...
# 5      [{'id': 12244321730616, 'title': 'Default Titl...
# 6      [{'id': 12244321697848, 'title': 'Default Titl...
# 7      [{'id': 12244321534008, 'title': 'Default Titl...
# 8      [{'id': 12244321206328, 'title': 'Default Titl...
# 9      [{'id': 12244321173560, 'title': 'Default Titl...
# 10     [{'id': 12243592314936, 'title': 'Default Titl...
# 11     [{'id': 12243592052792, 'title': 'Default Titl...
# 12     [{'id': 12243591987256, 'title': 'Default Titl...
# 13     [{'id': 12243591888952, 'title': 'Default Titl...
# 14     [{'id': 12243591856184, 'title': 'Default Titl...
# 15     [{'id': 12243591823416, 'title': 'Default Titl...
# ...
